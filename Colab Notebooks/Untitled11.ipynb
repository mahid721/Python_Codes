# %%
set_1 = {1, 'dileep', 'dasari', 2, 5, 'mahesh', 4, 5, 6, 7}



set_2 = {1, 'dileep', 'dasari', 2, 5, 'mahesh', 4, 5, 6, 1, 233}

set_1.isdisjoint(set_2)
# Out:
# False

# %%
s1 = {1, 2, 3, 4, 5, 10, 20}

s2 = {10, 20, 30, 1, 2, 3, 40, 50}

s1.symmetric_difference_update(s2)

print(s1)
print(s2)
# Out:
# {4, 5, 40, 50, 30}
# {1, 2, 3, 40, 10, 50, 20, 30}

# %%
s27 = {1, 2, 3, 4, 5, 6, 7, 'mahesh'}
s28 = {1, 2, 3, 4, 5,100, 200, 400}
s27.symmetric_difference_update(s28)
print(s27)
# Out:
# {100, 6, 7, 200, 400, 'mahesh'}
