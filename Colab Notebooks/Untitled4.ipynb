# %%
len = 10
a = 10
b = 20
if a < b:
  print(a+b)
print(len(str(a)))
# Out:
# 30
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-f13af46ff948> in <module>()
#       4 if a < b:
#       5   print(a+b)
# ----> 6 print(len(str(a)))
#       7
#       8
#
# TypeError: 'int' object is not callable

# %%
jhdfkzfiud

# %%
jsagiy
