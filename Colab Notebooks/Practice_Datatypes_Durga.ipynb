# %%
a = 19798328

len(str(a))
# Out:
# 8

# %%
a=10
b=1
print(type(a))
print(id(a))
print(id(b))
# Out:
# <class 'int'>
# 11256352
# 11256064

# %%
a=4555555515634562515555226879422
print(a)
# Out:
# 4555555515634562515555226879422

# %%
a=0b1111
print(a)
# Out:
# 15

# %%
a=0o1237
print(a)
# Out:
# 671

# %%
a=0xface
print(a)
# Out:
# 64206

# %%
bin(15)
# Out:
# '0b1111'

# %%
bin(0o456)
# Out:
# '0b100101110'

# %%
bin(0xfde459)
# Out:
# '0b111111011110010001011001'

# %%
oct(12549)
# Out:
# '0o30405'

# %%
oct(0b1010)
# Out:
# '0o12'

# %%
oct(0xdf9856)
# Out:
# '0o67714126'

# %%
hex(45862)
# Out:
# '0xb326'

# %%
hex(0b101011)
# Out:
# '0x2b'

# %%
hex(0o457124)
# Out:
# '0x25e54'

# %%
f=1.55455
print(type(f))
# Out:
# <class 'float'>

# %%
f=1.5e6
print(f)
# Out:
# 1500000.0

# %%
f=1.555555
print(f)
# Out:
# 1.555555

# %%
f=0c1245.56
print(f)
# Out:
#   File "<ipython-input-33-4045f0eaf974>", line 1
#     f=0c1245.56
#            ^
# SyntaxError: invalid syntax

# %%
x=10+20j
print(type(x))
# Out:
# <class 'complex'>

# %%
x=10+20j
print(x.imag)
# Out:
# 20.0

# %%
x=10+20j
print(x.real)
# Out:
# 10.0

# %%
x=10+70j
y=20+30j
print(x+y)
# Out:
# (30+100j)

# %%
x=0b1010111+25897j
print(x)
# Out:
# (87+25897j)

# %%
x=10.5+20.8j
print(x)
# Out:
# (10.5+20.8j)

# %%
x=12.5+0o4561j
print(x)
# Out:
#   File "<ipython-input-42-46a53cea9923>", line 1
#     x=12.5+0o4561j
#                  ^
# SyntaxError: invalid syntax

# %%
a=True
print(type(a))
# Out:
# <class 'bool'>

# %%
print(True+True)
print(True-False)
print(True*False)
# Out:
# 2
# 1
# 0

# %%
a=10
b=20
c=a>b
print(c)
# Out:
# False

# %%
s='durga'
print(type(s))
# Out:
# <class 'str'>

# %%
d='class by "durga" is very good'
print(d)
# Out:
# class by "durga" is very good

# %%
s="class by 'durga' is very good"
print(s)
# Out:
# class by 'durga' is very good

# %%
s='''durga
software 
solutions'''
print(s)
# Out:
# durga
# software
# solutions

# %%
s='durekjkihkjhifh'
print(s[0])
print(s[-1])
# Out:
# d
# h

# %%
s='kjdhvkhkjhkvh'
print(s[3:9])
# Out:
# hvkhkj

# %%
s='kjdhvkhkjhkvh'
print(s[:])
# Out:
# kjdhvkhkjhkvh

# %%
s='durga'
output=s[0].upper()+s[1:]
print(output)
# Out:
# Durga

# %%
s='durga'
output=s[0:len(s)-1]+s[-1].upper()
print(output)
# Out:
# durgA

# %%
s='durga'
output=s[0].upper()+s[1:len(s)-1]+s[-1].upper()
print(output)
# Out:
# DurgA

# %%
s='durga'
output=s[0:].upper()
print(output)
# Out:
# DURGA

# %%
s='durga'*'sonu'
print(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-94ac20c52b3d> in <module>()
# ----> 1 s='durga'*'sonu'
#       2 print(s)
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
s='durgs'*3
print(s)
# Out:
# durgsdurgsdurgs

# %%
s='ditgfg'+3
print(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-30e5ae4858c5> in <module>()
# ----> 1 s='ditgfg'+3
#       2 print(s)
#
# TypeError: can only concatenate str (not "int") to str

# %%
print('#'*10)
# Out:
# ##########

# %%
print('durgq')
# Out:
# durgq
