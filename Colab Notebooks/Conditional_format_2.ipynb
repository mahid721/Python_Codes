# %%
s= 'durga'
print('d'in s)
print('s' in s)
# Out:
# True
# False

# %%
s=input('enter a first string')
sub=input('enter a second string')
if sub in s:
  print(sub ,'is found in first string')
else:
  print(sub, 'is not in found in second' )
# Out:
# enter a first stringdurga
# enter a second stringdurga
# durga is found in first string

# %%
s1=input('enter a first string')
s2=input('enter a second string')
if s1==s2:
  print("both are equal")
elif s1>s2:
  print('first is greater then second one')
else:  
  print('first is smaller then second one')
# Out:
# enter a first stringdurga
# enter a second stringDurga
# first is greater then second one

# %%
l1=['a','d','c','e']
l2=['a','d','c','e']
print(l1 is l2)
print(l1==l2)
# Out:
# False
# True

# %%
l1=['a','d','c','e']
l1=['a','d','c','e']
print(l1 is l1)
print(l1==l1)
# Out:
# True
# True

# %%
city=input('enter a city:')
list=['hyd','mumbai','beng','pune']
if city.strip() in list:
  print(city,'city is available in list')
else:
  print(city,'city not available in list')
# Out:
# enter a city:     beng
#      beng city is available in list

# %%
s='abababa'
sub='ab'
l=len(s)
i=s.find(sub)
while i!=-1:
  print(sub,'present at index',i)
  i=s.find(sub,i+len(sub),l)
# Out:
# ab present at index 0
# ab present at index 2
# ab present at index 4
