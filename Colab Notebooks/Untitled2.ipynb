# %%
lst = [1,2,3,4,4,5]

del lst[2]
print(lst)

# del lst
# print(lst)
# Out:
# [1, 2, 4, 4, 5]

# %%
a = lst.remove(4)
print(a)
# Out:
# None

# %%
t1 = (10,20,'Mahesh','guru',10.5)
print(t1)
# Out:
# (10, 20, 'Mahesh', 'guru', 10.5)

# %%
ls1 = [10,20,30]
ls1.sort()
print(ls1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-921730725487> in <module>()
#       1 ls1 = [10,20,30]
# ----> 2 ls1.sort(1)
#       3 print(ls1)
#
# TypeError: sort() takes no positional arguments
