# %%
l1 = [10,20,30,40,10,20,50,10,60,10,10]


my_dict = {}
my_dict[l1[0]] = l1.count(l1[0]) 
my_dict[l1[1]] = l1.count(l1[1])
my_dict[l1[2]] = l1.count(l1[2])
my_dict[l1[3]] = l1.count(l1[3])
my_dict[l1[4]] = l1.count(l1[4])
my_dict[l1[5]] = l1.count(l1[5])
my_dict[l1[6]] = l1.count(l1[6])
my_dict[l1[7]] = l1.count(l1[7])
my_dict[l1[8]] = l1.count(l1[8])
my_dict[l1[9]] = l1.count(l1[9])
my_dict[l1[10]] = l1.count(l1[10])



for x in range(len(l1)):
   my_dict[l1[x]] = l1.count(l1[x])


print(my_dict)

del(my_dict)
# Out:
# {10: 5, 20: 2, 30: 1, 40: 1, 50: 1, 60: 1}

# %%
def Dictionary_fun(l1):
  my_dict = {}
  for x in range(len(l1)):
    my_dict[l1[x]] = l1.count(l1[x])
  print(my_dict)

Dictionary_fun(l1)


def Dictionary_fun(l1):
  my_dict = {}
  n=0
  for x in range(len(l1)):
    for y in l1:

  my_dict[l1[x]] = 
  print(my_dict) 

Dictionary_fun(l1)
# Out:
#   File "<ipython-input-17-59c391c90a33>", line 17
#     my_dict[l1[x]] =  1
#     ^
# IndentationError: expected an indented block

# %%
# string formatting fuctions


# types of string formatting ----------------

    # 1.Positional formatting
    # 2.Formatted string literals
    # 3.Template method 


# >>>>>>>>>>>>>>>>>> Positional formatting <<<<<<<<<<<<<<<<<<<<<<<<<

#  String.Format Method --- Mostly used method
#  syntax : 'text{}'.format(value)



print('{a} is a good boy, he is {b}'.format(b='Software Engineer',a='Mahesh'))

Name= 'Gurunadh'
Study = 'CA'
print('My brother is {Name} , He is studying {Study}')


# >>>>>  Name Placeholders

Personal_info = 'My Name is {}, I am working as {} ,my Current Loaction is {}, I am working with {}'
name = 'Mahesh Dasari'
designation = 'Software Engineer'
city = 'Mumbai'
company = 'RBL bank'

print(Personal_info.format(name, designation, city, company))



print('My Name is {2}, I am working with {1}, I am working as {0}, my Current Loaction is {3}'.format(designation, company, name, city))

print('My Name is {name}, I am working as {designation} ,my Current Loaction is {city}, I am working with {company}'.format(name = name,designation = designation, city = city, company = company  ))


my_methods = { 'name' : name,'designation' : designation, 'city' : city, 'company' : company }

print('My Name is {data[name]}, I am working as {data[designation]} ,my Current Loaction is {data[city]}, I am working with {data[company]}'.format(data = my_methods))




print("Only {0:.2f}% of the {1} produced worldwide is {2}!". format( 0.5155675, "data", "analyzed"))
# Out:
# Mahesh is a good boy, he is Software Engineer
# My brother is {Name} , He is studying {Study}
# My Name is Mahesh Dasari, I am working as Software Engineer ,my Current Loaction is Mumbai, I am working with RBL bank
# My Name is Mahesh Dasari, I am working with RBL bank, I am working as Software Engineer, my Current Loaction is Mumbai
# My Name is Mahesh Dasari, I am working as Software Engineer ,my Current Loaction is Mumbai, I am working with RBL bank
# My Name is Mahesh Dasari, I am working as Software Engineer ,my Current Loaction is Mumbai, I am working with RBL bank
# Only 0.52% of the data produced worldwide is analyzed!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-cf407b07be12> in <module>()
#      45 print("Only {0:.2f}% of the {1} produced worldwide is {2}!". format(0.5155675, "data", "analyzed"))
#      46
# ---> 47 print(datetime.now())
#
# ...

# %%
from datetime import datetime

print(datetime.now())

Today = datetime.now()
print(Today)
 
print(Today.strftime("%b")) # to get Month Name >> April,June

print(Today.strftime("%A")) # to get Week day >> monday tuesday
# Out:
# 2022-04-12 15:26:23.881917
# 2022-04-12 15:26:23.882863
# Apr
# Tuesday

# %%
L_1 = [1,2,3,4,5] # To find given list are circular  or not , 0,1,2,3,4
L_2 = [3,4,5,1,2]

IS_Circular = True
if len(L_1) == len(L_2):
  for i in range(len(L_1)):
    temp1 = L_1[i]
    if temp1 in L_2:
      if i == 0 :
        l1 = L_1[-1]
        r1 = L_1[i+1]
      elif i == len(L_1)-1: 
        l1 = L_1[i-1]
        r1 = L_1[0] 
      else:
          l1 = L_1[i-1]
          r1 = L_1[i+1]
    y = L_2.index(temp1)
    temp2 = L_2[y]
    if y == 0 :
      l2 = L_2[-1]
      r2 = L_2[y+1]
    elif y == len(L_2)-1:
      l2 = L_2[y-1]
      r2 = L_2[0] 
    else:
        l2 = L_2[y-1]
        r2 = L_2[y+1]
    if r1 != r2:
      IS_Circular = False
      print('L_2 not a circular')
      break
    if l2 != l1:
      IS_Circular = False
      print('L_2 not a circular')
      break
    print(i,temp1,r1,l1)
    print(y,temp2,r2,l2)
else:
  IS_Circular = False
  print('L_2 is not a circular of L_1')
# Out:
# L_2 not a circular

# %%
l1 = [10,20,30,40]

l1.index(10)
# Out:
# 0

# %%
# To find duplicates

from iteration_utilities import duplicates
ll1 = [1,2,3,4,5,6,1,5,3,10,10]

temp = list(duplicates(ll1))
print(ll1)



from iteration_utilities import unique_everseen
 
if __name__ == '__main__':
 
    nums = [1, 5, 2, 1, 4, 5, 1]
 
    dup = unique_everseen(duplicates(nums))
    print(dup)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-26-4357274cafaf> in <module>()
#       1 # To find duplicates
#       2
# ----> 3 from iteration_utilities import duplicates
#       4 ll1 = [1,2,3,4,5,6,1,5,3,10,10]
#       5
#
# ModuleNotFoundError: No module named 'iteration_utilities'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
ll1 = [1,2,3,4,5,6,1,5,3,10,10]
for x in ll1:       # to find duplicates to print as a set
  if ll1.count(x) > 1:
    print(set({x}))



l1 = [5,5,5,5]   # >>> to multify of elements in the list
i=1  
for x in l1:
  i = i*x
print(i)


l_1 = [10,20,70,100,1000,5000,1000,300,60,60]
max(l_1)
min(l_1)





def match_words(words):
  ctr = 0

  for word in words:
    if len(word) > 1 and word[0] == word[-1]:
      ctr = ctr + 1
      ww = word
      print(ww)

print(match_words(['abc', 'xyz', 'aba', '1221','mam']))



   
a = ['python is very easy']    

if 'is' in a:
    print('is avaible in a')
# Out:
# {1}
# {3}
# {5}
# {1}
# {5}
# {3}
# {10}
# {10}
# 625
# aba
# 1221
# None

# %%
a = ('python is very easy') 

if a.find('very easy') == -1:
  print('no string like very easy here!')
else:
  print('very is avalable in string: ',a)



  
if ("is") in a:
  print('no string like very easy here!')
else:
  print('very is avalable in string: ',a)
# Out:
# very is avalable in string:  python is very easy
# no string like very easy here!

# %%
# %a	Weekday, short version                      --ex--                    	Wed	
# %A	Weekday, full version	                      --ex-                       Wednesday	
# %w	Weekday  as a number 0-6, 0 is Sunday       --ex--                      3	
# %d	Day of month 01-31	                        --ex-                       31
# %b	Month name,             short version	                                  Dec	
# %B	Month name, full version	                                              December	
# %m	Month as a number 01-12	                                                12	
# %y	Year, short version, without century              	                    18	
# %Y	Year, full version	                                                    2018	
# %H	Hour 00-23	                                                            17	
# %I	Hour 00-12                                        	                    05	
# %p	AM/PM	                                                                  PM	
# %M	Minute 00-59	                                                          41	
# %S	Second 00-59	                                                          08	
# %f	Microsecond 000000-999999	                                              548513	
# %z	UTC offset	                                                            +0100	
# %Z	Timezone	                                                              CST	
# %j	Day number of year 001-366	                                           365	
# %U	Week number of year, Sunday as the first day of week, 00-53	          52	
# %W	Week number of year, Monday as the first day of week, 00-53	          52	
# %c	Local version of date and time	                                      Mon Dec 31 17:41:00 2018	
# %C	Century	                                                              20	
# %x	Local version of date	                                                12/31/18	
# %X	Local version of time	                                                17:41:00	
%%	A % character	                                                        %	
# %G	ISO 8601 year	                                                        2018	
# %u	ISO 8601 weekday (1-7)	                                              1	
# %V	ISO 8601 weeknumber (01-53)                                         	01

# %%
x = abs(-7.25) # to get positive only

print(x)


x = min(5, 10, 25)
y = max(5, 10, 25)



a = pow(4, 3) # The pow(a, b) function returns the value of a to the power of b (a^b).

import math   # math module 


x = math.sqrt(64)   # The math.sqrt() method for example, returns the square root of a number:



# >>>>> The math.ceil() method rounds a number upwards to its nearest integer
# >>>>> the math.floor() method rounds a number downwards to its nearest integer, and returns the result:
x = math.ceil(1.4) ##  toget overall value 2
y = math.floor(1.4) # to get overall value 1

print(x) # returns 2
print(y) # returns 1

x = math.pi  # The math.pi constant, returns the value of PI (3.14...):

# %%
l_1 = [20,30,40,10,50,60,70,30,10,200,500,300,200,10,200,10]

for y in range(len(l_1)): 
    if l_1[y] == 10:
        l_1[y] = 100
    elif l_1[y] == 200:
            l_1[y] = 20
print(l_1)

# >>>>>>>>>>>>>  Different scenario 
ll = ['a','b','c','d']

ll = [0,1,2,3]

for ll[-1] in ll:
  print(ll[-1],end = '')
# Out:
# [20, 30, 40, 100, 50, 60, 70, 30, 100, 20, 500, 300, 20, 100, 20, 100]
# 0122

# %%
def count_list(x):
  n = 0
  for i in x:
      n= n+i
  return n

print(count_list([10,20,30,40,10,20,50,10,60,10,10]))
# Out:
# 270

# %%
d1 = {'Name':'Mahesh','Age':24, 'village':'NKBD', 'education':'B\'Tech'} # Creating a dictionary 1.order is preserved in new version

print(d1['Name']) # to get value for given key ,1.requires one argument ;  2.return the value,

print(d1.get('Name')) # to get value for given key : 1.requires one argument : 2.return the value  of given key:
t1 = d1.get('Name')
print('temp t1 : ',t1)


d1['designation'] = 'software developer'  # adding a new key,value to excisting dictionary 
d1.update({'Father':'SRINIVASULU'})       # adding a new key,value to excisting dictionary 
d2 = d1.copy()

print('dictionary d1 : ' ,d1)
print('dictionary d2 : ' ,d2)

d3 = {1:'Monday',2:'Tuesday',3:'wednesday'} 


print('dictionary d3 : ' ,d3)

print('Keys of dictionry d3 : ', d3.keys() ) # to get keys of given dictionary ,: 1.no argument required  : 2.return the  keys of given dictionary

d4 =d3.keys()                     # 1.no argument required  : 2.return the  keys of given dictionary
print('dictionary d4 : ' ,d4)




print('Values of dictionry d3 : ', d3.values() ) # to get Values of given dictionary ,: 1.no argument required  : 2.return the  Values of given dictionary


d3[1] = 'Saturday'        # to modify the excisting value for same key >> we can modify the values but keys cannot change 
print('dictionary d3 : ' ,d3)

d1.update(d3)               #  1.requires one argument : 2. returns None:
temp1 = d1.update(d3) 
print('temp1 : ',temp1)


print('length of dictionary :' ,len(d1)) # to find no of key:value pairs are there / length of dictionary ,1.requires one argument : 2. returns the length in number

print('dictionary d1 : ' ,d1)






print(d1.items())  # to print key,value in a tuple : 1.no argument required ,2.return the result as key,values in tuple

temp2 = d1.items()
print('temp2 :' , temp2)

temp = d1.clear() # >> method to del dictionary 1.no argument required , 2.returns None  
print(temp)

del(d1) # >> function to del dictionary   , 1.no argument required , 2.returns None 

del(d1['education']) # >> function to del key of dictionary   , 1.one argument required , 2.returns None
# Out:
# Mahesh
# Mahesh
# temp t1 :  Mahesh
# dictionary d1 :  {'Name': 'Mahesh', 'Age': 24, 'village': 'NKBD', 'education': "B'Tech", 'designation': 'software developer'}
# dictionary d2 :  {'Name': 'Mahesh', 'Age': 24, 'village': 'NKBD', 'education': "B'Tech", 'designation': 'software developer'}
# dictionary d3 :  {1: 'Monday', 2: 'Tuesday', 3: 'wednesday'}
# Keys of dictionry d3 :  dict_keys([1, 2, 3])
# dictionary d4 :  dict_keys([1, 2, 3])
# ['Age', 'Name', 'designation', 'education', 'village']
# list of li =  [24, 'Mahesh', 'software developer', "B'Tech", 'NKBD']
# dd is a dictionaary {'Age': 24, 'Name': 'Mahesh', 'designation': 'software developer', 'education': "B'Tech", 'village': 'NKBD'}
# Values of dictionry d3 :  dict_values(['Monday', 'Tuesday', 'wednesday'])
# dictionary d3 :  {1: 'Saturday', 2: 'Tuesday', 3: 'wednesday'}
# temp1 :  None
# length of dictionary : 8
# ...

# %%
# to sort the dictionary 

sor = sorted(d1.keys())  # sorting keys and storing in list of sor

print(sor)
li = []   # Creating a empty list to store tha values of keys from d1 dictionary in the form of sor list
for x in sor:   # storing the values of sor list in li list from dictionary
  li.append(d1[x])
print('list of li = ',li)
dd = dict(zip(sor,li)) # finally creating dictionary using sorted keys and values by using sor list and li list   
print('dd is a dictionaary',dd)

# %%
d1 = {'Name':'Mahesh','Age':24, 'village':'NKBD', 'education':'B\'Tech'} # to create a dictionary


def dictionary_1 (dict1): # print a dictionary using User define function
  for x in dict1:
    print(x,':',dict1[x])

dictionary_1(d1)
# Out:
# Name : Mahesh
# Age : 24
# village : NKBD
# education : B'Tech

# %%
l1 = [10,20,30,40,10,20,50,10,60,10,10]

m_dict = {}

'''

m_dict[l1[0]] = l1.count(l1[0]) # 1st key
m_dict[l1[1]] = l1.count(l1[1]) 
m_dict[l1[4]] = l1.count(l1[4]) 
'''




for x in range(len(l1)):
   m_dict[l1[x]] = l1.count(l1[x])
print(m_dict)



temp = 0
for x in range(len(l1)):
   m_dict[l1[x]] = 1
print(m_dict)
# Out:
# {10: 5, 20: 2, 30: 1, 40: 1, 50: 1, 60: 1}
# {10: 1, 20: 1, 30: 1, 40: 1, 50: 1, 60: 1}
